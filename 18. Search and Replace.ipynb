# %%
search_word = 'Potassium Parmanganate'
replace_word = 'KMnO4'

with open(r'sss.txt', 'r') as file:
    dev = file.read()
    dev = dev.replace(search_word, replace_word)

# %%
with open(r'sss.txt', 'w') as file:
    file.write(dev)
