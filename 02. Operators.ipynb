# %%
x = 27
y = 4
z = 13
a = 135791113151719
b = 135791113151719
c = [4,6,7,'DEV', [2,5,'BAU'], 9]

print('Addition of x, y, and z:', x+y+z)
print('Subtraction from x to y, and z:', x-y-z)
print('Multiplication of x, y, and z:', x*y*z)
print('Division of x by y:', x/y)
print('\n')
print('Taking just integer value of x divided by y:', x//y)
print('z to the power y:', z**y)
print('\n')
print('a is equal to b:', a is b)
print('DEV exists in c:', 'DEV' in c)   # Membership operator
print('7 does not exist in c:', 7 not in c)   # Membership operator
print('\n')
print('x is less than or equal to z:', x<=z)
print ('a is equal to b:', a==b)
print('x>z and y>z , is it correct?:', x>z and y>z)
print('x>z or y<z , is it correct?:', x>z or y<z)
print('x>z and y<z , is it incorrect?:', not(x>z and y<z))
# Out:
# Addition of x, y, and z: 44
# Subtraction from x to y, and z: 10
# Multiplication of x, y, and z: 1404
# Division of x by y: 6.75
#
#
# Taking just integer value of x divided by y: 6
# z to the power y: 28561
#
#
# a is equal to b: False
# DEV exists in c: True
# 7 does not exist in c: False
#
#
# x is less than or equal to z: False
# a is equal to b: True
# x>z and y>z , is it correct?: False
# x>z or y<z , is it correct?: True
# x>z and y<z , is it incorrect?: False

# %%
a = float(input('Enter the first number:'))
b = float(input('Enter the second number:'))
c = a//b
d = a % b
print('\nThe float division is:', c)
print('\nThe modulus is:', round(d, 3), '\n')
# Out:
# The float division is: 0.0
#
# The modulus is: 23.61
